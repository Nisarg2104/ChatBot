# %%
# !pip install bert-for-tf2
# !pip install tensorflow-text
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bert-for-tf2
#   Downloading bert-for-tf2-0.14.9.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 9.5 kB/s eta 0:00:011
# Collecting py-params>=0.9.6
#   Downloading py-params-0.10.2.tar.gz (7.4 kB)
# Collecting params-flow>=0.8.0
#   Downloading params-flow-0.8.2.tar.gz (22 kB)
# Requirement already satisfied: numpy in /home/sun/.local/lib/python3.6/site-packages (from params-flow>=0.8.0->bert-for-tf2) (1.19.5)
# Requirement already satisfied: tqdm in /home/sun/.local/lib/python3.6/site-packages (from params-flow>=0.8.0->bert-for-tf2) (4.62.3)
# Building wheels for collected packages: bert-for-tf2, params-flow, py-params
#   Building wheel for bert-for-tf2 (setup.py) ... done
#   Created wheel for bert-for-tf2: filename=bert_for_tf2-0.14.9-py3-none-any.whl size=30536 sha256=ca0be507652f2b015c53d9b30bf6a3387083c45c75ffbf0f8c63ebd409aad53a
#   Stored in directory: /home/sun/.cache/pip/wheels/19/18/97/0d58cab1b354f98e6b1b3791e9b2dc14ce537d63daec0d4924
#   Building wheel for params-flow (setup.py) ... done
#   Created wheel for params-flow: filename=params_flow-0.8.2-py3-none-any.whl size=19471 sha256=491b0fd947a58894a75c6cbf9fb2906eac99fc093d1fee735c67a44372009d7f
#   Stored in directory: /home/sun/.cache/pip/wheels/9d/c6/c5/a3f4a618640f461130f47e76703156c13a39cc3b96b5f4f439
#   Building wheel for py-params (setup.py) ... done
#   Created wheel for py-params: filename=py_params-0.10.2-py3-none-any.whl size=7910 sha256=bc41ca950b82a44bd0178650f8bde8e1360c1be80994e4dc8a61f63fd22796fa
#   Stored in directory: /home/sun/.cache/pip/wheels/48/77/b1/d0b01d524d972512852e1fc23b197ad9d3d1685e349b8cabb6
# Successfully built bert-for-tf2 params-flow py-params
# Installing collected packages: py-params, params-flow, bert-for-tf2
# Successfully installed bert-for-tf2-0.14.9 params-flow-0.8.2 py-params-0.10.2
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 159 kB/s eta 0:00:01     |████▌                           | 614 kB 2.7 MB/s eta 0:00:02     |██████████████████████▏         | 3.1 MB 2.7 MB/s eta 0:00:01
# Collecting tensorflow-hub>=0.8.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: tensorflow<2.7,>=2.6.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow-text) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.7.4.3)
# Requirement already satisfied: clang~=5.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (5.0)
# Requirement already satisfied: astunparse~=1.6.3 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: absl-py~=0.10 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.12.0)
# Requirement already satisfied: h5py~=3.1.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.37.1)
# Requirement already satisfied: termcolor~=1.1.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.1.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.12)
# Requirement already satisfied: gast==0.4.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.19.5)
# Requirement already satisfied: wrapt~=1.12.1 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.12.1)
# Requirement already satisfied: keras~=2.6 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.16.0)
# Requirement already satisfied: six~=1.15.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /home/sun/.local/lib/python3.6/site-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.36.2)
# Requirement already satisfied: cached-property in /home/sun/.local/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/sun/.local/lib/python3.6/site-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (56.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sun/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sun/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/sun/.local/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/sun/.local/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.3.0)
# Requirement already satisfied: importlib-metadata in /home/sun/.local/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.0.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/sun/.local/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2018.1.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sun/.local/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2.0.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sun/.local/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/sun/.local/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.4.1)
# Installing collected packages: tensorflow-hub, tensorflow-text
# Successfully installed tensorflow-hub-0.12.0 tensorflow-text-2.6.0

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from bert import bert_tokenization
import numpy as np

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# %%
def get_model(model_url, max_seq_length):
  inputs = dict(
    input_word_ids=tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32),
    input_mask=tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32),
    input_type_ids=tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32),
    )

  muril_layer = hub.KerasLayer(model_url, trainable=True)
  outputs = muril_layer(inputs)

  assert 'sequence_output' in outputs
  assert 'pooled_output' in outputs
  assert 'encoder_outputs' in outputs
  assert 'default' in outputs
  return tf.keras.Model(inputs=inputs,outputs=outputs["pooled_output"]), muril_layer

# %%
max_seq_length = 128
muril_model, muril_layer = get_model(
    model_url="https://tfhub.dev/google/MuRIL/1", max_seq_length=max_seq_length)

# %%
vocab_file = muril_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = muril_layer.resolved_object.do_lower_case.numpy()
tokenizer = bert_tokenization.FullTokenizer(vocab_file, do_lower_case)

# %%
def create_input(input_strings, tokenizer, max_seq_length):
  input_ids_all, input_mask_all, input_type_ids_all = [], [], []
  for input_string in input_strings:
    input_tokens = ["[CLS]"] + tokenizer.tokenize(input_string) + ["[SEP]"]
    input_ids = tokenizer.convert_tokens_to_ids(input_tokens)
    sequence_length = min(len(input_ids), max_seq_length)
    
    if len(input_ids) >= max_seq_length:
      input_ids = input_ids[:max_seq_length]
    else:
      input_ids = input_ids + [0] * (max_seq_length - len(input_ids))

    input_mask = [1] * sequence_length + [0] * (max_seq_length - sequence_length)

    input_ids_all.append(input_ids)
    input_mask_all.append(input_mask)
    input_type_ids_all.append([0] * max_seq_length)
  
  return np.array(input_ids_all), np.array(input_mask_all), np.array(input_type_ids_all)

# %%
def encode(input_text):
  input_ids, input_mask, input_type_ids = create_input(input_text, 
                                                       tokenizer, 
                                                       max_seq_length)
  inputs = dict(
      input_word_ids=input_ids,
      input_mask=input_mask,
      input_type_ids=input_type_ids,
  )
  return muril_model(inputs)

# %%
sentences = []
for intent in intents:

# %%
embeddings = encode(sentences)

# %%
print(embeddings[0])
# Out:
# tf.Tensor(
# [ 8.95485841e-03  1.89020280e-02 -7.59345340e-03  1.52121596e-02
#  -7.93804042e-03 -8.57562479e-03 -1.93336117e-03 -5.10400208e-03
#  -3.53488768e-03 -9.13775247e-03 -9.48588084e-03  5.13539184e-03
#   1.81499927e-03  6.02441083e-04 -4.70407167e-03  1.73263885e-02
#   2.03459687e-03 -8.91160779e-03 -9.37851146e-05 -5.40853105e-03
#   6.16519526e-03  6.18503778e-04  6.52640685e-03 -2.47494802e-02
#   5.86105371e-03  1.31967885e-03 -7.87752029e-03 -6.26218459e-03
#   4.24759230e-04 -2.27475259e-02  1.28376335e-02  1.42989531e-02
#   6.05618209e-03 -1.60678178e-02  2.25728732e-02  7.26900622e-03
#   8.11308995e-03 -1.45411212e-02  6.73037628e-03 -6.73705433e-03
#  -2.16814149e-02 -1.60372723e-02  2.90697720e-03  2.11845320e-02
#  -1.95993613e-02 -9.07351729e-04 -2.52701784e-03 -1.23210372e-02
#  -6.18797075e-03 -8.72047269e-04 -1.02474242e-02 -3.45041975e-03
#   1.57834962e-02  1.27798226e-02 -5.76535473e-03 -1.59886815e-02
#   9.89234308e-04 -1.06833447e-02 -7.23856827e-03  2.16629952e-02
#  -8.37345317e-04  1.74116611e-03 -4.16379597e-04  3.51045281e-03
#  -4.67023533e-03  1.25401495e-02  2.98637408e-03  9.70551511e-04
#   1.29548749e-02  7.49735767e-03  7.98926689e-03  1.07012242e-02
#   8.42084829e-03 -1.12954003e-03  1.40547166e-02  2.56368192e-03
#   1.48905581e-02  5.32520842e-03  9.30963457e-03  1.52270058e-02
#  -8.07245541e-03 -1.19992569e-02  1.04648331e-02 -1.06369825e-02
#   9.80904792e-04 -2.66787782e-03  9.23589803e-03 -1.00067502e-03
#   9.27392859e-03 -7.31344894e-03  1.55770872e-02 -2.65183747e-02
#  -2.35138694e-04 -1.09257130e-02  7.93079566e-03 -2.16914490e-02
#   5.86609263e-03  4.49367985e-03  1.56547893e-02 -5.59481326e-03
#   5.64222131e-03 -1.22081805e-02  8.50073819e-04  2.20494461e-03
#  -7.05353450e-05  1.24132233e-02  2.92349234e-03  1.47250798e-02
#   1.94892157e-02 -2.29835836e-03  2.81158909e-02 -4.43869038e-03
#  -8.27656407e-03  9.01015941e-04  2.13400889e-02 -5.15521411e-03
#  -1.20013962e-02  1.31211327e-02  2.21126876e-03  3.81076941e-03
#   1.63805410e-02  5.84588572e-03 -4.81506251e-03  5.83635317e-03
#  -4.02510446e-03  1.18375188e-02 -1.69912856e-02 -3.00051738e-03
#  -3.41042364e-03 -2.15379223e-02 -1.57398917e-02  2.45979521e-03
#  -7.87541829e-03  2.32311198e-03  1.35317976e-02  3.57718556e-03
#  -1.83146391e-02 -2.02925745e-02 -7.65999593e-03 -4.19397932e-03
#  -9.93901212e-03 -8.13102257e-03 -1.87548529e-02 -7.23342551e-03
#  -1.54239386e-02  1.82306226e-02 -2.04225304e-03  5.84321620e-04
#  -1.45223755e-02  1.88586414e-02  1.29499193e-02  1.29378997e-02
#   8.67193448e-04  2.21324095e-04  6.55937474e-03  4.92041977e-03
#   1.84373409e-02  7.51479063e-03 -6.93964539e-03 -7.77521823e-03
#   1.09562101e-02 -2.09418181e-02 -9.93888918e-03 -1.15890196e-02], shape=(768,), dtype=float32)

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/sun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/sun/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('data.json',encoding='utf-8').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 530 documents
# 33 classes ['', 'affirm', 'crm_application', 'cz_acd', 'cz_bar', 'cz_bot', 'cz_callback', 'cz_callblast', 'cz_chat', 'cz_conference', 'cz_dialer', 'cz_guide', 'cz_helpdesk', 'cz_ivr', 'cz_lms', 'cz_magic_call', 'cz_missed_call', 'cz_mobile', 'cz_screen_logger', 'cz_voice_logger', 'deny', 'greet', 'home', 'manual_dialer', 'non_voice_process', 'predictive_dialer', 'preview_dialer', 'product', 'progressive_dialer', 'self_service_solutions', 'thankyou', 'voice_process', 'work_force_management']
# 228 unique lemmatized words [',', 'bot', 'c', 'cz', 'czentrix', 'helpdesk', 'ivr', 'mobile', 'thankyou', 'अच्छा', 'अनुप्रयोग', 'अपने', 'अलविदा', 'आईवीआर', 'आप', 'आपकी', 'आपके', 'आपने', 'आवश्यकता', 'आवाज', 'आवाज़', 'आवेदन', 'आस', 'इन', 'उत्पाद', 'उत्पादों', 'उपाय', 'एक', 'एजेंटों', 'एप्लिकेशन', 'एप्लीकेशन', 'एलएमएस', 'एसीडी', 'ओह', 'ओहक', 'कंपनी', 'कभी', 'कर', 'करता', 'करती', 'करते', 'करने', 'करें', 'कहनेवाला', 'का', 'कांफ्रेस', 'कार्य', 'कार्यबल', 'कितने', 'किस', 'की', 'के', 'केंद्र', 'कैक्लबैक', 'कॉन्फरेन्स', 'कॉल', 'कॉलबैक', 'कॉलब्लास्ट', 'क्या', 'गए', 'गया।', 'गाइड', 'गैर', 'गैरआवाज', 'गैरआवाज़', 'गैरध्वनि', 'गैरप्रक्रिया', 'चाहता', 'चाहते', 'चाहिए', 'चियर्स', 'चूक', 'चेज़ेंट्रिक्स', 'चैट', 'चैटिंग', 'चैत', 'जरूरत', 'जांच', 'जाए', 'जादू', 'जानकारी', 'ट्रांसफरिंग', 'ठंडा', 'ठीक', 'डाइविंग', 'डायल', 'डायलर', 'डायलिंग', 'डेस्क', 'तरह', 'तलाश', 'तात', 'थानकीउ', 'थान्यकौ', 'थैंकीउ', 'थैंक्यू', 'देख', 'देखो', 'देवता', 'द्वारा', 'धन्यवाद', 'नमस्ते', 'नहीँ', 'नहीं', 'ना', 'नॉन', 'पर', 'पास', 'पुकार', 'पूर्वावलोकन', 'पूर्वावलोकनडायलर', 'पेश', 'प्रकार', 'प्रक्रिया', 'प्रगतिशील', 'प्रडिक्टिव', 'प्रडिक्टिवडायलर', 'प्रणाली', 'प्रदान', 'प्रबंधन', 'प्रभात', 'प्रिडिक्टिव', 'प्रीव्यू', 'प्रेडिक्टिव', 'प्रॊगरेशिव', 'प्रोग्रेसिव', 'प्रोडक्ट', 'प्रोसेस', 'फिर', 'फीचर', 'बता', 'बताएं', 'बताओ', 'बताता', 'बल', 'बातचीत', 'बाद', 'बाय', 'बार', 'बारे', 'बेशक', 'बैक', 'बॉट', 'बोली', 'ब्लास्ट', 'भविष्य', 'भविष्यवाणियों', 'भविष्यवाणी', 'भाग', 'भीतर', 'मदद', 'मार्गदर्शक', 'मिलते', 'मिलेंगे', 'मिस', 'मिस्ड', 'मुझे', 'में', 'मेरी', 'मैं', 'मैजिक', 'मैनुअल', 'मैनेजमेंट', 'मोड', 'मोड।', 'मोबाइल', 'रहे', 'रूटिंग', 'लकड़हारा', 'लकड़हारे', 'लिए', 'लॉग', 'लॉगर', 'लॉगरसुविधा', 'वर्कफोर्स', 'वापस', 'वितरक', 'विवरण', 'विस्फोट', 'वॉइस', 'वॉयस', 'शुभ', 'संबंधित', 'संबंधी', 'सकते', 'समझ', 'समाधान', 'सम्मेलन', 'सर्विस', 'सहायता', 'साथ', 'सी.जेड', 'सीआरएम', 'सीआरएमआवेदन', 'सीज', 'सीज़ेंट्रिक्स', 'सीज़ेंट्रिक्स-सम्मेलन', 'सीज़ेंट्रिक्सआईवीआर', 'सीज़ेंट्रिक्सगाइड', 'सीज़ेंट्रिक्सहेल्पडेस्क', 'सीजी', 'सीजेड', 'सीसेंट्रिक्स', 'सुनो', 'सुविधा', 'सुसंध्या', 'से', 'सेल्फ', 'सेवा', 'सॉल्यूशंस', 'सॉल्यूशन', 'स्क्रीन', 'स्वचालित', 'स्वयं', 'हम्मम', 'हाँ', 'हां', 'हांजी', 'हूँ', 'हे', 'हेल्प', 'हेल्पडेस्क', 'है', 'हैं', 'हैं।', 'हैलो', 'है।', 'होम']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(33, activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist
200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.3141 - accuracy: 0.8981
# Epoch 52/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2962 - accuracy: 0.9019
# Epoch 53/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2705 - accuracy: 0.9075
# Epoch 54/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.9075
# Epoch 55/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8736
# Epoch 56/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.8962
# Epoch 57/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9132
# Epoch 58/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2638 - accuracy: 0.9057
# Epoch 59/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2747 - accuracy: 0.8981
# Epoch 60/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9321
# Epoch 61/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2832 - accuracy: 0.8943
# Epoch 62/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.9189
# Epoch 63/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9038
# Epoch 64/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.9094
# Epoch 65/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.9094
# Epoch 66/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.8962
# Epoch 67/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.8925
# Epoch 68/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.9057
# Epoch 69/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9057
# Epoch 70/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9094
# Epoch 71/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8792
# Epoch 72/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8981
# Epoch 73/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9113
# Epoch 74/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9208
# Epoch 75/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1882 - accuracy: 0.9396
# Epoch 76/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2049 - accuracy: 0.9358
# Epoch 77/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1923 - accuracy: 0.9321
# Epoch 78/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9226
# Epoch 79/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1775 - accuracy: 0.9264
# Epoch 80/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2212 - accuracy: 0.9113
# Epoch 81/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2884 - accuracy: 0.9000
# Epoch 82/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3090 - accuracy: 0.8868
# Epoch 83/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9038
# Epoch 84/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9208
# Epoch 85/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.9302
# Epoch 86/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2248 - accuracy: 0.9113
# Epoch 87/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2022 - accuracy: 0.9302
# Epoch 88/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2164 - accuracy: 0.9264
# Epoch 89/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9321
# Epoch 90/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2276 - accuracy: 0.9264
# Epoch 91/200
# 106/106 [==============================] - 0s 4ms/step - loss: 0.1803 - accuracy: 0.9415
# Epoch 92/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2016 - accuracy: 0.9321
# Epoch 93/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1999 - accuracy: 0.9151
# Epoch 94/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.1888 - accuracy: 0.9302
# Epoch 95/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1789 - accuracy: 0.9358
# Epoch 96/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9245
# Epoch 97/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9113
# Epoch 98/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9132
# Epoch 99/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9132
# Epoch 100/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1825 - accuracy: 0.9377
# Epoch 101/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2040 - accuracy: 0.9226
# Epoch 102/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9472
# Epoch 103/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9264
# Epoch 104/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2107 - accuracy: 0.9170
# Epoch 105/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.9038
# Epoch 106/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2199 - accuracy: 0.9226
# Epoch 107/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.9000
# Epoch 108/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.9208
# Epoch 109/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2004 - accuracy: 0.9321
# Epoch 110/200
# 106/106 [==============================] - 0s 3ms/step - loss: 0.2453 - accuracy: 0.9151
# Epoch 111/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1804 - accuracy: 0.9358
# Epoch 112/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.
200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1903 - accuracy: 0.9358
# Epoch 175/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9226
# Epoch 176/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9340
# Epoch 177/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9245
# Epoch 178/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1600 - accuracy: 0.9340
# Epoch 179/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1800 - accuracy: 0.9245
# Epoch 180/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.9264
# Epoch 181/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9189
# Epoch 182/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9302
# Epoch 183/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9472
# Epoch 184/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1621 - accuracy: 0.9377
# Epoch 185/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9434
# Epoch 186/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9415
# Epoch 187/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9396
# Epoch 188/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9491
# Epoch 189/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9358
# Epoch 190/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2056 - accuracy: 0.9226
# Epoch 191/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1928 - accuracy: 0.9264
# Epoch 192/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9170
# Epoch 193/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1691 - accuracy: 0.9226
# Epoch 194/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1854 - accuracy: 0.9358
# Epoch 195/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9434
# Epoch 196/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2154 - accuracy: 0.9189
# Epoch 197/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.9321
# Epoch 198/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9132
# Epoch 199/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1879 - accuracy: 0.9415
# Epoch 200/200
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9340
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('data.json',encoding='utf-8').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
